# %% [markdown]
# # Predecir un parámetro en función otras variables
#
# Se intentará predecir la Tonalidad del sonido en función de otras variables. Definiendo variables dicotómicas para aquellas variables categóricas que así lo requieran.

# %%
import pandas as pd
import numpy as np

from sklearn import linear_model
import statsmodels.api as sm

np.set_printoptions(precision=2)

# %%
data = pd.read_csv('snd-dataset-from-plain-json.csv')
data.head()
# Out:
#      Duration   Loudness  LogAttackTime  Tempo  Tempo.confidence  \
# 0   24.218412 -16.581459       0.769376     95          0.133154
# 1  243.983673 -16.891335       1.618665     65          0.545527
# 2   15.281632 -21.658251       0.582658     63          0.996905
# 3    2.000000 -10.525232      -1.590209    119          0.000000
# 4    1.454150 -28.335722      -0.492548    152          0.000000
#
#    TemporalCentroid  SingleEvent   Loop  Tonality  Tonality.confidence  \
# 0          0.498596        False  False   G major             0.524679
# 1          0.479576        False  False   G major             0.785114
# 2          0.492315         True   True   C minor             0.698095
# 3          0.468918        False  False  G# minor             0.646680
# 4          0.502481         True  False  F# minor             0.408481
#
#    DynamicRange  Note.midi  Note.frequency  Note.confidence    Genre    Mood
# 0      9.689243         55      197.972900         0.000000  Genre B  Mood B
# 1      5.247044         40       85.456451         0.000000  Genre A  Mood A
# 2      1.060242         50      151.972198         0.352345  Genre B  Mood B
# 3      0.000000         41       91.402817         0.000000  Genre A  Mood A
# 4      0.000000        107     3984.657227         0.695633  Genre A  Mood A

# %%
data.shape[0]
# Out:
# 1017

# %%
# Se descartan columnas que tienen que ver con la confianza
# en las estimaciones en el cálculo de features
# Tip: axis number (0 for rows and 1 for columns)
data = data.drop("Tempo.confidence", axis=1);
data = data.drop("Tonality.confidence", axis=1);
data = data.drop("Note.confidence", axis=1);

# Según la documentación (Referencia: https://github.com/AudioCommons/ac-audio-extractor) Genre y Mood
# todavía no están correctamente implementadas, así que se descarta su valor
data = data.drop("Genre", axis=1);
data = data.drop("Mood", axis=1);

# %% [markdown]
# ### Correlación entre variables

# %%
data.corr(method='pearson', min_periods=1) # pearson -> método estándar
# Out:
#                   Duration  Loudness  LogAttackTime     Tempo  \
# Duration          1.000000  0.081523       0.501519  0.104969
# Loudness          0.081523  1.000000       0.060905  0.035220
# LogAttackTime     0.501519  0.060905       1.000000  0.071875
# Tempo             0.104969  0.035220       0.071875  1.000000
# TemporalCentroid  0.258024  0.046486       0.340716  0.072140
# SingleEvent      -0.232345 -0.465222      -0.238297 -0.021407
# Loop             -0.233539 -0.070003      -0.234266 -0.159896
# DynamicRange      0.318640 -0.118577       0.359254  0.046447
# Note.midi        -0.154564 -0.105028      -0.054808  0.012247
# Note.frequency   -0.133548 -0.122475      -0.100731  0.034907
#
#                   TemporalCentroid  SingleEvent      Loop  DynamicRange  \
# Duration                  0.258024    -0.232345 -0.233539      0.318640
# Loudness                  0.046486    -0.465222 -0.070003     -0.118577
# LogAttackTime             0.340716    -0.238297 -0.234266      0.359254
# Tempo                     0.072140    -0.021407 -0.159896      0.046447
# TemporalCentroid          1.000000    -0.187250 -0.136633      0.038687
# SingleEvent              -0.187250     1.000000  0.163248     -0.118497
# Loop                     -0.136633     0.163248  1.000000     -0.088077
# DynamicRange              0.038687    -0.118497 -0.088077      1.000000
# Note.midi                -0.007034     0.128890  0.047451      0.093423
# Note.frequency           -0.021946     0.155892  0.078194      0.002418
#
#                   Note.midi  Note.frequency
# Duration          -0.154564       -0.133548
# Loudness          -0.105028       -0.122475
# LogAttackTime     -0.054808       -0.100731
# Tempo              0.012247        0.034907
# TemporalCentroid  -0.007034       -0.021946
# SingleEvent        0.128890        0.155892
# Loop               0.047451        0.078194
# DynamicRange       0.093423        0.002418
# Note.midi          1.000000        0.801161
# Note.frequency     0.801161        1.000000

# %% [markdown]
# **Observación: La correlación entre variables en general es baja, salvo en duración con LogAttackTime, DynamicRange y TemporalCentroid en menor medida.**

# %% [markdown]
# ## Regresión múltiple (varias variables)

# %%
# Referencia: https://stackoverflow.com/questions/11479064/multiple-linear-regression-in-python
def reg_multiple(y, x):
    ones = np.ones(len(x[0]))
    X = sm.add_constant(np.column_stack((x[0], ones)))
    for ele in x[1:]:
        X = sm.add_constant(np.column_stack((ele, X)))
    results = sm.OLS(y, X).fit()
    return results

# %%
Duration = np.asarray( data.loc[:, 'Duration' ] )
DynamicRange = np.asarray( data.loc[:, 'DynamicRange' ] )
TemporalCentroid = np.asarray( data.loc[:, 'TemporalCentroid' ] )
LogAttackTime = np.asarray( data.loc[:, 'LogAttackTime' ] )

# %%
y = LogAttackTime
X = np.array( [Duration, DynamicRange])

reg_multiple(y, X).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     213.0
# Date:                Wed, 19 Dec 2018   Prob (F-statistic):           6.06e-78
# Time:                        19:22:42   Log-Likelihood:                -1329.5
# No. Observations:                1017   AIC:                             2665.
# Df Residuals:                    1014   BIC:                             2680.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0442      0.006      7.985      0.000       0.033       0.055
# x2             0.0026      0.000     15.495      0.000       0.002       0.003
# const          0.2564      0.047      5.403      0.000       0.163       0.349
# ==============================================================================
# Omnibus:                      158.744   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              235.732
# Skew:                          -1.112   Prob(JB):                     6.48e-52
# Kurtosis:                       3.788   Cond. No.                         407.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Observación: El R cuadrado no llega a 0.3, cuando se espera algo por lo menos de 0.5.**

# %% [markdown]
# ## Se agrega el feature TemporalCentroid

# %%
y = LogAttackTime
X = np.array( [Duration, DynamicRange, TemporalCentroid])

reg_multiple(y, X).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     180.4
# Date:                Wed, 19 Dec 2018   Prob (F-statistic):           1.04e-93
# Time:                        19:22:44   Log-Likelihood:                -1290.2
# No. Observations:                1017   AIC:                             2588.
# Df Residuals:                    1013   BIC:                             2608.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             3.6500      0.404      9.027      0.000       2.857       4.443
# x2             0.0464      0.005      8.715      0.000       0.036       0.057
# x3             0.0022      0.000     13.205      0.000       0.002       0.003
# const         -1.5264      0.203     -7.530      0.000      -1.924      -1.129
# ==============================================================================
# Omnibus:                      163.368   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              247.697
# Skew:                          -1.111   Prob(JB):                     1.63e-54
# Kurtosis:                       3.951   Cond. No.                     4.00e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Observación: El valor de R cuadrado mejora, pero no se alcanza un valor de p > 0.005 que defina un 95% de confianza.**

# %% [markdown]
# ## Variables categóricas  y conversión a dummy dicotómicas

# %% [markdown]
# **La asignación de un número a cada categoría no resuelve el problema. La solución es crear tantas variables dicotómicas como número de respuestas. Para k valores posibles, se toman k-1 variables dicotómicas.**

# %% [markdown]
# ### Key o Tonality
#
# Las categorias posibles para la tonalidad se encuentran en notación americana, donde 'A' es La, 'B' es Sí, etc. Se expresan en el array 'key_to_number_list' y luego se mapean en 23 variables dicotómicas, ya que la cantidad de valores posibles es 24.
#
# ### Genre, Loop y Mood
#
# Género, si es loopeable y Mood (humor) se mapean en una única variable dicotómica ya que poseen solo dos valores posibles.
#
# Según la documentación (https://github.com/AudioCommons/ac-audio-extractor) Genre y Mood
# todavía no están correctamente implementadas, así que se descarta su valor y queda temporalmente deshabilitado

# %%
data
# Out:
#          Duration   Loudness  LogAttackTime  Tempo  TemporalCentroid  \
# 0       24.218412 -16.581459       0.769376     95          0.498596
# 1      243.983673 -16.891335       1.618665     65          0.479576
# 2       15.281632 -21.658251       0.582658     63          0.492315
# 3        2.000000 -10.525232      -1.590209    119          0.468918
# 4        1.454150 -28.335722      -0.492548    152          0.502481
# 5      267.807343 -10.931602       1.392732    120          0.520935
# 6       88.000000 -23.165480       1.241127    117          0.458141
# 7      165.276733 -11.126256       1.022743    129          0.508618
# 8        3.813878 -18.993910       0.283296    108          0.645547
# 9       38.000000 -25.768625       0.658518    138          0.537336
# 10       8.000023 -13.546592      -1.615867    120          0.439625
# 11      44.000000 -11.980686       1.099768    178          0.469863
# 12     348.421234  -9.933128       1.267178    148          0.513269
# 13     206.863678 -13.644941       0.450766     90          0.466386
# 14      11.937959 -31.162172       0.351986    164          0.518048
# 15       9.116735 -23.519577       0.466891    105          0.497343
# 16      26.209547 -19.770998       1.064859     84          0.525173
# 17      25.846146 -12.103339       1.080958    130          0.520540
# 18     192.992661 -25.856901      -0.035720    185          0.383731
# 19     204.904495 -13.773675       1.277696    118          0.494020
# 20     246.047348 -13.444487       1.883148    120          0.594818
# 21      52.010860 -46.690449       0.882473    120          0.501421
# 22      86.400002 -15.122791      -1.262962    100          0.477449
# 23       9.728000 -15.029512      -0.099738     89          0.508425
# 24     100.512001 -15.996842       1.612585    103          0.437528
# 25     128.735992 -13.466563       1.805198    178          0.552175
# 26      44.000000 -21.197809       1.041875    120          0.422069
# 27     202.240005 -16.906498       1.904938    100          0.599641
# 28    1015.465210 -29.270380       1.866576    123          0.367776
# 29     110.889793 -13.462910       1.659830     97          0.505704
# ...           ...        ...            ...    ...               ...
# 987     47.542858 -19.405355       1.549231     92          0.563916
# 988     28.055510 -15.254635       0.909356     99          0.509541
# 989    304.117554 -24.180363       2.236083    100          0.560067
# 990    211.983673 -11.925678       0.761411    115          0.502060
# 991    121.704491 -14.874849       1.460731    129          0.510137
# 992    201.064484 -17.994726       1.514238    136          0.564425
# 993    226.298782 -31.995314       1.857398    118          0.463088
# 994    288.626953  -8.105678       1.476120    129          0.481273
# 995    187.271835 -24.332481       1.010081    100          0.508656
# 996     57.417141 -18.143353       1.714564    115          0.524931
# 997    262.817963 -11.585208       0.720546     92          0.503626
# 998      1.717914 -31.278513      -0.020002    131          0.524127
# 999    196.832657 -10.920163       1.473007     95          0.533917
# 1000    53.339954 -14.418766       0.134234     90          0.405105
# 1001   134.000000  -6.889537       2.037036    103          0.474061
# 1002    42.000023 -28.977671       0.617243     60          0.536200
# 1003    27.468000 -12.471481       0.692837    115          0.516148
# 1004   154.462036  -9.433309       1.323963     86          0.464185
# 1005    26.385532 -23.287800       1.036314    108          0.458203
# 1006    66.716736 -11.397777       1.592665    115          0.498273
# 1007    38.000000 -25.768625       0.658518    138          0.537336
# 1008     4.000000 -11.840410      -1.554533    119          0.500155
# 1009   272.440002  -7.484704       0.840197    135          0.505030
# 1010   996.668640 -33.324051       2.717680    129          0.513614
# 1011    24.048000 -32.243423       1.149651    144          0.596042
# 1012   133.895996 -17.324625       2.042675    116          0.634760
# 1013   191.895508 -29.433876       0.995865     90          0.380662
# 1014   291.134705 -12.455325       2.298327    126          0.518228
# 1015     4.504671 -11.448072      -0.604470    109          0.483486
# 1016   219.977142 -25.957409       1.571033    126          0.530384
#
#       SingleEvent   Loop  Tonality  DynamicRange  Note.midi  Note.frequency  \
# 0           False  False   G major      9.689243         55      197.972900
# 1           False  False   G major      5.247044         40       85.456451
# 2            True   True   C minor      1.060242         50      151.972198
# 3           False  False  G# minor      0.000000         41       91.402817
# 4            True  False  F# minor      0.000000        107     3984.657227
# 5           False  False   C major      6.640100         49      143.887039
# 6           False  False  A# major      9.204067         57      220.011536
# 7           False  False   D major      3.703292         45      110.599480
# 8           False  False   D minor      0.593395         61      293.014404
# 9           False  False   G major      6.336580         44      108.097351
# 10          False  False   E minor      3.090756         53      182.669281
# 11          False  False   C major      5.372542         58      236.818970
# 12          False  False   D minor     13.174868         52      173.257843
# 13          False  False   B minor      4.273746         56      212.180038
# 14          False  False   E major      0.119370         35       64.411896
# 15           True  False  D# minor      0.790110         62      308.103760
# 16          False  False   E minor      7.490688         68      431.838379
# 17          False   True   G major      2.702969         57      220.777771
# 18          False  False  D# minor      4.440586         75      635.025269
# 19          False  False   B minor      3.288824         56      212.945343
# 20          False  False   E minor     16.536821         55      196.049744
# 21           True   True   E minor      4.374847         53      179.457687
# 22          False  False   C major      2.206399         59      260.552704
# 23          False  False   E minor      1.331486         64      330.137024
# 24          False  False  A# major      6.179472         58      239.308380
# 25          False  False   C major     10.506671         55      201.959015
# 26           True   True   F minor      0.737228         60      276.590942
# 27          False  False   D major     19.490517         73      554.883118
# 28          False  False   D major     20.706423         53      179.137909
# 29          False  False   E minor      3.148008         59      253.272095
# ...           ...    ...       ...           ...        ...             ...
# 987         False  False  F# minor     10.277987         54      191.415131
# 988         False  False   A minor      1.556336         58      245.512314
# 989         False  False  D# major     12.545227         63      311.295654
# 990         False  False  D# major      2.417801         51      155.972198
# 991         False  False   A major      7.749168         64      335.126923
# 992         False  False   A minor     10.356094         48      132.352341
# 993         False  False   D minor     10.831877         50      147.676422
# 994         False  False   G major      5.885442         62      297.910828
# 995         False  False   C major      2.113811         38       75.012947
# 996         False  False   D minor      5.977828         57      231.956116
# 997         False  False   G major      4.171823         56      219.528229
# 998          True  False   D minor      0.000000         55      199.342575
# 999         False  False   E minor      6.902799         52      172.825348
# 1000        False   True   F major      0.714869         56      214.598587
# 1001        False  False  A# major      1.324518         57      232.613708
# 1002        False   True   F major     11.334602         45      115.102776
# 1003        False  False   G major      2.598167         47      130.063599
# 1004        False  False   A minor     17.289953         56      219.851700
# 1005        False  False   D major      6.052818         61      280.857483
# 1006        False  False   A major      2.783530         50      147.899765
# 1007        False  False   G major      6.336580         44      108.097351
# 1008        False  False  D# minor      0.247951         41       91.551239
# 1009        False  False   B major      4.132440         58      245.857239
# 1010        False  False   C minor     24.117083         55      200.602402
# 1011         True  False  D# minor      5.036406         41       89.474052
# 1012        False  False  A# major     17.878475         70      472.791992
# 1013        False  False   G major      7.808306         53      183.851807
# 1014        False  False  G# major      4.633302         55      196.884644
# 1015        False  False  C# minor      0.431854         74      621.745239
# 1016        False  False   F minor     14.514193         59      247.273514
#
#         Genre    Mood
# 0     Genre B  Mood B
# 1     Genre A  Mood A
# 2     Genre B  Mood B
# 3     Genre A  Mood A
# 4     Genre A  Mood A
# 5     Genre B  Mood B
# 6     Genre A  Mood A
# 7     Genre B  Mood B
# 8     Genre A  Mood A
# 9     Genre B  Mood B
# 10    Genre A  Mood A
# 11    Genre A  Mood A
# 12    Genre B  Mood B
# 13    Genre A  Mood A
# 14    Genre A  Mood A
# 15    Genre B  Mood B
# 16    Genre A  Mood A
# 17    Genre A  Mood A
# 18    Genre A  Mood A
# 19    Genre A  Mood A
# 20    Genre A  Mood A
# 21    Genre A  Mood A
# 22    Genre A  Mood A
# 23    Genre A  Mood A
# 24    Genre A  Mood A
# 25    Genre A  Mood A
# 26    Genre A  Mood A
# 27    Genre A  Mood A
# 28    Genre B  Mood B
# 29    Genre A  Mood A
# ...       ...     ...
# 987   Genre B  Mood B
# 988   Genre B  Mood B
# 989   Genre B  Mood B
# 990   Genre A  Mood A
# 991   Genre B  Mood B
# 992   Genre B  Mood B
# 993   Genre A  Mood A
# 994   Genre A  Mood A
# 995   Genre A  Mood A
# 996   Genre B  Mood B
# 997   Genre A  Mood A
# 998   Genre A  Mood A
# 999   Genre B  Mood B
# 1000  Genre B  Mood B
# 1001  Genre B  Mood B
# 1002  Genre A  Mood A
# 1003  Genre B  Mood B
# 1004  Genre B  Mood B
# 1005  Genre B  Mood B
# 1006  Genre B  Mood B
# 1007  Genre B  Mood B
# 1008  Genre A  Mood A
# 1009  Genre A  Mood A
# 1010  Genre B  Mood B
# 1011  Genre B  Mood B
# 1012  Genre A  Mood A
# 1013  Genre A  Mood A
# 1014  Genre A  Mood A
# 1015  Genre A  Mood A
# 1016  Genre B  Mood B
#
# [1017 rows x 13 columns]

# %%
# Para mapear el 'key' en cifrado americano a numeros enteros (relación lineal entre semi-tonos)
# La tonalidad (mayor/menor) se mapea por separado)
key_to_number_list = ['A','A#','B','C','C#','D','D#','E','F','F#','G','G#']

def keyToNumber(x_value):
    key, tonality = x_value.split(' ') # [key_cifrado_americano], [major/minor]
    return [i for i,x in enumerate(key_to_number_list) if x == key][0]

# %%
# Cantidad de dicotómicas
len(key_to_number_list)
# Out:
# 12

# %%
# Key
# Mapeo de las key/tonality 'en texto' a categorias numéricas
# Se necesitan k-1 variables dicotómicas, con k=len(key_to_number_list)
# Se separa en la key (A, A#, B, etc) y la tonalidad (mayor o menor)
# La primera utiliza 11 dicotómicas y la segunda se puede representar con una sola
#    (ya que tiene solo dos valores posibles)
data['D1'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==1 else 0)
data['D2'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==2 else 0)
data['D3'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==3 else 0)
data['D4'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==4 else 0)
data['D5'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==5 else 0)
data['D6'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==6 else 0)
data['D7'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==7 else 0)
data['D8'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==8 else 0)
data['D9'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==9 else 0)
data['D10'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==10 else 0)
data['D11'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==11 else 0)

data['T1'] = data['Tonality'].map(lambda x: 1 if x.split(' ')[1]=='major' else 0)

# Genre
#data['G1'] = data['Genre'].map(lambda x: 1 if x=='Genre A' else 0)

# Loopeable?
data['L1'] = data['Loop'].map(lambda x: 1 if x==True else 0)

# Mood
#data['M1'] = data['Mood'].map(lambda x: 1 if x=='Mood A' else 0)

data.head()
# Out:
#      Duration   Loudness  LogAttackTime  Tempo  TemporalCentroid  SingleEvent  \
# 0   24.218412 -16.581459       0.769376     95          0.498596        False
# 1  243.983673 -16.891335       1.618665     65          0.479576        False
# 2   15.281632 -21.658251       0.582658     63          0.492315         True
# 3    2.000000 -10.525232      -1.590209    119          0.468918        False
# 4    1.454150 -28.335722      -0.492548    152          0.502481         True
#
#     Loop  Tonality  DynamicRange  Note.midi ...  D4  D5  D6  D7  D8  D9  D10  \
# 0  False   G major      9.689243         55 ...   0   0   0   0   0   0    1
# 1  False   G major      5.247044         40 ...   0   0   0   0   0   0    1
# 2   True   C minor      1.060242         50 ...   0   0   0   0   0   0    0
# 3  False  G# minor      0.000000         41 ...   0   0   0   0   0   0    0
# 4  False  F# minor      0.000000        107 ...   0   0   0   0   0   1    0
#
#    D11  T1  L1
# 0    0   1   0
# 1    0   1   0
# 2    0   0   1
# 3    1   0   0
# 4    0   0   0
#
# [5 rows x 24 columns]

# %%
L1 = np.asarray( data.loc[:, 'L1' ] )

# Genre y Mood todavía no están correctamente implementadas (ver documentación), así que se descarta su valor
# y queda temporalmente deshabilitado
#G1 = np.asarray( data.loc[:, 'G1' ] )
#M1 = np.asarray( data.loc[:, 'M1' ] )

D1 = np.asarray( data.loc[:, 'D1' ] )
D2 = np.asarray( data.loc[:, 'D2' ] )
D3 = np.asarray( data.loc[:, 'D3' ] )
D4 = np.asarray( data.loc[:, 'D4' ] )
D5 = np.asarray( data.loc[:, 'D5' ] )
D6 = np.asarray( data.loc[:, 'D6' ] )
D7 = np.asarray( data.loc[:, 'D7' ] )
D8 = np.asarray( data.loc[:, 'D8' ] )
D9 = np.asarray( data.loc[:, 'D9' ] )
D10 = np.asarray( data.loc[:, 'D10' ] )
D11 = np.asarray( data.loc[:, 'D11' ] )

T1 = np.asarray( data.loc[:, 'T1' ] )

# %%
# Regresión mutivariable con dicotómicas

y = LogAttackTime
#X = np.array( [Duration, DynamicRange, TemporalCentroid, G1, L1, M1, D1, D2, D3, D4, D5, D6,D7,D8,D9,D10,D11,T1])
X = np.array( [Duration, DynamicRange, TemporalCentroid, L1, T1, D1,D2,D3,D4,D5,D6,D7,D8,D9,D10,D11])

reg_multiple(y, X).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.382
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     38.64
# Date:                Wed, 19 Dec 2018   Prob (F-statistic):           5.86e-93
# Time:                        19:25:10   Log-Likelihood:                -1263.1
# No. Observations:                1017   AIC:                             2560.
# Df Residuals:                    1000   BIC:                             2644.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.6162      0.146     -4.234      0.000      -0.902      -0.331
# x2            -0.0139      0.105     -0.132      0.895      -0.220       0.193
# x3             0.0059      0.143      0.041      0.967      -0.275       0.287
# x4            -0.3064      0.131     -2.341      0.019      -0.563      -0.050
# x5            -0.2025      0.103     -1.965      0.050      -0.405      -0.000
# x6            -0.5211      0.165     -3.151      0.002      -0.846      -0.197
# x7            -0.0951      0.106     -0.899      0.369      -0.303       0.113
# x8            -0.1082      0.177     -0.611      0.541      -0.456       0.239
# x9            -0.0449      0.107     -0.421      0.674      -0.254       0.165
# x10           -0.1979      0.131     -1.510      0.131      -0.455       0.059
# x11           -0.2368      0.133     -1.782      0.075      -0.498       0.024
# x12            0.0870      0.056      1.554      0.121      -0.023       0.197
# x13           -0.3575      0.098     -3.635      0.000      -0.551      -0.165
# x14            3.4746      0.400      8.680      0.000       2.689       4.260
# x15            0.0466      0.005      8.843      0.000       0.036       0.057
# x16            0.0020      0.000     11.871      0.000       0.002       0.002
# const         -1.2773      0.215     -5.943      0.000      -1.699      -0.856
# ==============================================================================
# Omnibus:                      159.021   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              241.958
# Skew:                          -1.072   Prob(JB):                     2.88e-53
# Kurtosis:                       4.056   Cond. No.                     4.07e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Observación: El valor de R cuadrado (coeficiente de determinación) mejora.**

# %% [markdown]
# ## Otra estrategia: limpiar un poco más el dataset

# %%
data.shape[0]
# Out:
# 1017

# %% [markdown]
# ### Se filtran los 'single events' ya que se asume que no son canciones
#
# Es decir 'eventos únicos', no van a caracterizar bien tonalidad, género, etc.

# %%
data = data[~data['SingleEvent'].isin([True])] 
data = data.drop("SingleEvent", axis=1);

data.shape[0]
# Out:
# 871

# %% [markdown]
# ### Se mantienen solo los sonidos de más de 120 segundos (canciones )
#
# Criterio: Se filtran los sonidos de más de 2 minutos y menos de 5, para restringir el dataset a canciones más convencionales (menos experimentales, muy cortas o muy largas).

# %%
data = data[ data['Duration'] > 60*2 ]
data = data[ data['Duration'] < 60*5 ]
data.shape[0]
# Out:
# 399

# %% [markdown]
# Queda un total de casi 400 instancias

# %% [markdown]
# ## Correlación

# %%
data.corr(method='pearson', min_periods=1) # pearson -> método estándar
# Out:
#                   Duration  Loudness  LogAttackTime     Tempo  \
# Duration          1.000000  0.138401       0.078643  0.073934
# Loudness          0.138401  1.000000      -0.035528  0.000409
# LogAttackTime     0.078643 -0.035528       1.000000  0.025246
# Tempo             0.073934  0.000409       0.025246  1.000000
# TemporalCentroid -0.052267 -0.084362       0.196094  0.034338
# Loop                   NaN       NaN            NaN       NaN
# DynamicRange     -0.137162 -0.385033       0.184478  0.080032
# Note.midi        -0.136723 -0.140231      -0.134777  0.064543
# Note.frequency   -0.092955 -0.211257      -0.128704 -0.013254
# D1               -0.095537 -0.068300      -0.111130 -0.035142
# D2               -0.028614 -0.005083      -0.059607 -0.001918
# D3               -0.017545  0.017989       0.105207 -0.026285
# D4               -0.021973  0.089250       0.033036  0.122586
# D5                0.052853 -0.004584       0.025346  0.084164
# D6               -0.022756 -0.064297       0.022829  0.134019
# D7                0.062770  0.076069      -0.023403 -0.073791
# D8                0.069183  0.037078       0.017756  0.014462
# D9                0.041269  0.063008      -0.002290 -0.053636
# D10              -0.013114 -0.021518       0.040939  0.017622
# D11              -0.003025 -0.058731      -0.100108  0.010571
# T1               -0.040923  0.029375       0.042504  0.034097
# L1                     NaN       NaN            NaN       NaN
#
#                   TemporalCentroid  Loop  DynamicRange  Note.midi  \
# Duration                 -0.052267   NaN     -0.137162  -0.136723
# Loudness                 -0.084362   NaN     -0.385033  -0.140231
# LogAttackTime             0.196094   NaN      0.184478  -0.134777
# Tempo                     0.034338   NaN      0.080032   0.064543
# TemporalCentroid          1.000000   NaN      0.101423  -0.000020
# Loop                           NaN   NaN           NaN        NaN
# DynamicRange              0.101423   NaN      1.000000   0.195923
# Note.midi                -0.000020   NaN      0.195923   1.000000
# Note.frequency           -0.033961   NaN      0.091224   0.819797
# D1                       -0.116078   NaN      0.111339   0.145437
# D2                       -0.017333   NaN     -0.045609   0.030188
# D3                        0.018570   NaN      0.007211  -0.043288
# D4                        0.020961   NaN      0.016609   0.001431
# D5                       -0.016378   NaN     -0.051923  -0.076440
# D6                        0.151150   NaN      0.026341   0.137204
# D7                        0.047303   NaN     -0.061919  -0.097094
# D8                       -0.025000   NaN      0.005620   0.011968
# D9                       -0.024908   NaN     -0.107705   0.090194
# D10                      -0.002158   NaN     -0.021539  -0.042814
# D11                       0.072472   NaN     -0.029221   0.027604
# T1                        0.046326   NaN      0.035657   0.041740
# L1                             NaN   NaN           NaN        NaN
#
#                   Note.frequency        D1 ...        D4        D5        D6  \
# Duration               -0.092955 -0.095537 ... -0.021973  0.052853 -0.022756
# Loudness               -0.211257 -0.068300 ...  0.089250 -0.004584 -0.064297
# LogAttackTime          -0.128704 -0.111130 ...  0.033036  0.025346  0.022829
# Tempo                  -0.013254 -0.035142 ...  0.122586  0.084164  0.134019
# TemporalCentroid       -0.033961 -0.116078 ...  0.020961 -0.016378  0.151150
# Loop                         NaN       NaN ...       NaN       NaN       NaN
# DynamicRange            0.091224  0.111339 ...  0.016609 -0.051923  0.026341
# Note.midi               0.819797  0.145437 ...  0.001431 -0.076440  0.137204
# Note.frequency          1.000000  0.120906 ... -0.015301 -0.031122  0.055945
# D1                      0.120906  1.000000 ... -0.038679 -0.091854 -0.038679
# D2                     -0.012690 -0.060650 ... -0.044454 -0.105569 -0.044454
# D3                     -0.022793 -0.079837 ... -0.058518 -0.138967 -0.058518
# D4                     -0.015301 -0.038679 ...  1.000000 -0.067326 -0.028351
# D5                     -0.031122 -0.091854 ... -0.067326  1.000000 -0.067326
# D6                      0.055945 -0.038679 ... -0.028351 -0.067326  1.000000
# D7                     -0.073325 -0.093782 ... -0.068739 -0.163240 -0.068739
# D8                     -0.001087 -0.045402 ... -0.033278 -0.079028 -0.033278
# D9                      0.131475 -0.046952 ... -0.034414 -0.081726 -0.034414
# D10                    -0.000113 -0.104120 ... -0.076317 -0.181235 -0.076317
# D11                    -0.001857 -0.040451 ... -0.029649 -0.070410 -0.029649
# T1                      0.058266  0.047819 ... -0.000308  0.057680 -0.031055
# L1                           NaN       NaN ...       NaN       NaN       NaN
#
#                         D7        D8        D9       D10       D11        T1  \
# Duration          0.062770  0.069183  0.041269 -0.013114 -0.003025 -0.040923
# Loudness          0.076069  0.037078  0.063008 -0.021518 -0.058731  0.029375
# LogAttackTime    -0.023403  0.017756 -0.002290  0.040939 -0.100108  0.042504
# Tempo            -0.073791  0.014462 -0.053636  0.017622  0.010571  0.034097
# TemporalCentroid  0.047303 -0.025000 -0.024908 -0.002158  0.072472  0.046326
# Loop                   NaN       NaN       NaN       NaN       NaN       NaN
# DynamicRange     -0.061919  0.005620 -0.107705 -0.021539 -0.029221  0.035657
# Note.midi        -0.097094  0.011968  0.090194 -0.042814  0.027604  0.041740
# Note.frequency   -0.073325 -0.001087  0.131475 -0.000113 -0.001857  0.058266
# D1               -0.093782 -0.045402 -0.046952 -0.104120 -0.040451  0.047819
# D2               -0.107785 -0.052181 -0.053963 -0.119667 -0.046491 -0.106176
# D3               -0.141884 -0.068689 -0.071035 -0.157525 -0.061199  0.056923
# D4               -0.068739 -0.033278 -0.034414 -0.076317 -0.029649 -0.000308
# D5               -0.163240 -0.079028 -0.081726 -0.181235 -0.070410  0.057680
# D6               -0.068739 -0.033278 -0.034414 -0.076317 -0.029649 -0.031055
# D7                1.000000 -0.080687 -0.083442 -0.185040 -0.071889 -0.102761
# D8               -0.080687  1.000000 -0.040396 -0.089582 -0.034803  0.021292
# D9               -0.083442 -0.040396  1.000000 -0.092641 -0.035991 -0.172992
# D10              -0.185040 -0.089582 -0.092641  1.000000 -0.079813  0.238949
# D11              -0.071889 -0.034803 -0.035991 -0.079813  1.000000  0.042551
# T1               -0.102761  0.021292 -0.172992  0.238949  0.042551  1.000000
# L1                     NaN       NaN       NaN       NaN       NaN       NaN
#
#                   L1
# Duration         NaN
# Loudness         NaN
# LogAttackTime    NaN
# Tempo            NaN
# TemporalCentroid NaN
# Loop             NaN
# DynamicRange     NaN
# Note.midi        NaN
# Note.frequency   NaN
# D1               NaN
# D2               NaN
# D3               NaN
# D4               NaN
# D5               NaN
# D6               NaN
# D7               NaN
# D8               NaN
# D9               NaN
# D10              NaN
# D11              NaN
# T1               NaN
# L1               NaN
#
# [22 rows x 22 columns]

# %% [markdown]
# **Observación: La correlación baja.**

# %% [markdown]
# ## Otra estrategia: Analizar los single events

# %%
data = pd.read_csv('snd-dataset-from-plain-json.csv')
data = data[data['SingleEvent'].isin([True])] 

data.shape[0]
# Out:
# 146

# %%
# eventos cortos
data = data[ data['Duration'] < 5 ]
data.shape[0]
# Out:
# 29

# %%
data.corr(method='pearson', min_periods=1) # pearson -> método estándar
# Out:
#                      Duration  Loudness  LogAttackTime     Tempo  \
# Duration             1.000000  0.409527       0.458463  0.413927
# Loudness             0.409527  1.000000       0.093151  0.011048
# LogAttackTime        0.458463  0.093151       1.000000  0.299679
# Tempo                0.413927  0.011048       0.299679  1.000000
# Tempo.confidence     0.109870  0.254183      -0.105107 -0.049662
# TemporalCentroid    -0.003603 -0.259784       0.646900  0.220953
# SingleEvent               NaN       NaN            NaN       NaN
# Loop                 0.111727  0.254445      -0.106338 -0.049214
# Tonality.confidence  0.267255  0.122818       0.292855  0.106185
# DynamicRange         0.314945  0.344705      -0.274957  0.006667
# Note.midi           -0.140897 -0.113036       0.360239  0.195123
# Note.frequency      -0.048192 -0.263562       0.351031  0.199756
# Note.confidence      0.070128  0.137129       0.465610  0.195006
#
#                      Tempo.confidence  TemporalCentroid  SingleEvent  \
# Duration                     0.109870         -0.003603          NaN
# Loudness                     0.254183         -0.259784          NaN
# LogAttackTime               -0.105107          0.646900          NaN
# Tempo                       -0.049662          0.220953          NaN
# Tempo.confidence             1.000000         -0.096474          NaN
# TemporalCentroid            -0.096474          1.000000          NaN
# SingleEvent                       NaN               NaN          NaN
# Loop                         0.999910         -0.102161          NaN
# Tonality.confidence         -0.144554          0.340015          NaN
# DynamicRange                 0.173904         -0.656999          NaN
# Note.midi                   -0.070938          0.343358          NaN
# Note.frequency              -0.152904          0.257487          NaN
# Note.confidence             -0.010962          0.368906          NaN
#
#                          Loop  Tonality.confidence  DynamicRange  Note.midi  \
# Duration             0.111727             0.267255      0.314945  -0.140897
# Loudness             0.254445             0.122818      0.344705  -0.113036
# LogAttackTime       -0.106338             0.292855     -0.274957   0.360239
# Tempo               -0.049214             0.106185      0.006667   0.195123
# Tempo.confidence     0.999910            -0.144554      0.173904  -0.070938
# TemporalCentroid    -0.102161             0.340015     -0.656999   0.343358
# SingleEvent               NaN                  NaN           NaN        NaN
# Loop                 1.000000            -0.145321      0.180476  -0.070443
# Tonality.confidence -0.145321             1.000000     -0.285782  -0.502435
# DynamicRange         0.180476            -0.285782      1.000000  -0.121501
# Note.midi           -0.070443            -0.502435     -0.121501   1.000000
# Note.frequency      -0.152925            -0.548159     -0.129814   0.876432
# Note.confidence     -0.012989             0.184913     -0.149882   0.299826
#
#                      Note.frequency  Note.confidence
# Duration                  -0.048192         0.070128
# Loudness                  -0.263562         0.137129
# LogAttackTime              0.351031         0.465610
# Tempo                      0.199756         0.195006
# Tempo.confidence          -0.152904        -0.010962
# TemporalCentroid           0.257487         0.368906
# SingleEvent                     NaN              NaN
# Loop                      -0.152925        -0.012989
# Tonality.confidence       -0.548159         0.184913
# DynamicRange              -0.129814        -0.149882
# Note.midi                  0.876432         0.299826
# Note.frequency             1.000000         0.038768
# Note.confidence            0.038768         1.000000

# %% [markdown]
# **Observación:** Se observa que la variable LogAttackTime esta bastante correlacionada linealmente con Duration, TemporaCentroid, por lo cuál se espera una regresión aceptable.

# %%
Duration = np.asarray( data.loc[:, 'Duration' ] )
DynamicRange = np.asarray( data.loc[:, 'DynamicRange' ] )
TemporalCentroid = np.asarray( data.loc[:, 'TemporalCentroid' ] )
LogAttackTime = np.asarray( data.loc[:, 'LogAttackTime' ] )
#Tempo = np.asarray( data.loc[:, 'Tempo' ] )

y = LogAttackTime
X = np.array( [Duration, TemporalCentroid])

reg_multiple(y, X).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     22.21
# Date:                Wed, 19 Dec 2018   Prob (F-statistic):           2.37e-06
# Time:                        19:25:39   Log-Likelihood:                -19.970
# No. Observations:                  29   AIC:                             45.94
# Df Residuals:                      26   BIC:                             50.04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             3.6067      0.663      5.443      0.000       2.245       4.969
# x2             0.2551      0.066      3.867      0.001       0.119       0.391
# const         -2.9599      0.336     -8.805      0.000      -3.651      -2.269
# ==============================================================================
# Omnibus:                        3.600   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.165   Jarque-Bera (JB):                3.174
# Skew:                          -0.786   Prob(JB):                        0.205
# Kurtosis:                       2.604   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Se obtiene un valor aceptable de R cuadrado, pero no así para p**

# %% [markdown]
# ## Filtrar solo los features calculados con confianza alta

# %%
data = pd.read_csv('snd-dataset-from-plain-json.csv')

#data = data[ data['Tempo.confidence'] > 0.5 ]
data = data[ data['Tonality.confidence'] > 0.8 ]
data = data[ data['Note.confidence'] > 0.5 ]

data.shape[0]
# Out:
# 32

# %%
data.corr(method='pearson', min_periods=1) # pearson -> método estándar
# Out:
#                      Duration  Loudness  LogAttackTime     Tempo  \
# Duration             1.000000  0.304569       0.642006  0.242524
# Loudness             0.304569  1.000000      -0.079180  0.032689
# LogAttackTime        0.642006 -0.079180       1.000000  0.067663
# Tempo                0.242524  0.032689       0.067663  1.000000
# Tempo.confidence     0.034554 -0.122179      -0.020464 -0.510652
# TemporalCentroid     0.089504  0.044776       0.264089  0.338942
# SingleEvent               NaN       NaN            NaN       NaN
# Loop                -0.082728 -0.168705       0.165728 -0.309448
# Tonality.confidence  0.442781  0.144841       0.243919  0.231979
# DynamicRange         0.356598 -0.310329       0.513857 -0.068813
# Note.midi            0.067216  0.152639      -0.023101 -0.075381
# Note.frequency      -0.023755  0.116591      -0.142450 -0.055689
# Note.confidence     -0.234207 -0.320799      -0.225773 -0.125349
#
#                      Tempo.confidence  TemporalCentroid  SingleEvent  \
# Duration                     0.034554          0.089504          NaN
# Loudness                    -0.122179          0.044776          NaN
# LogAttackTime               -0.020464          0.264089          NaN
# Tempo                       -0.510652          0.338942          NaN
# Tempo.confidence             1.000000         -0.281462          NaN
# TemporalCentroid            -0.281462          1.000000          NaN
# SingleEvent                       NaN               NaN          NaN
# Loop                         0.774390         -0.069671          NaN
# Tonality.confidence         -0.058799          0.098502          NaN
# DynamicRange                 0.186137         -0.264802          NaN
# Note.midi                   -0.069464          0.258988          NaN
# Note.frequency              -0.061536          0.158615          NaN
# Note.confidence              0.280368          0.018859          NaN
#
#                          Loop  Tonality.confidence  DynamicRange  Note.midi  \
# Duration            -0.082728             0.442781      0.356598   0.067216
# Loudness            -0.168705             0.144841     -0.310329   0.152639
# LogAttackTime        0.165728             0.243919      0.513857  -0.023101
# Tempo               -0.309448             0.231979     -0.068813  -0.075381
# Tempo.confidence     0.774390            -0.058799      0.186137  -0.069464
# TemporalCentroid    -0.069671             0.098502     -0.264802   0.258988
# SingleEvent               NaN                  NaN           NaN        NaN
# Loop                 1.000000            -0.205802      0.084184  -0.125787
# Tonality.confidence -0.205802             1.000000      0.163412   0.062781
# DynamicRange         0.084184             0.163412      1.000000  -0.003761
# Note.midi           -0.125787             0.062781     -0.003761   1.000000
# Note.frequency      -0.147280             0.090452     -0.004028   0.955458
# Note.confidence      0.264528             0.062282     -0.211804   0.177491
#
#                      Note.frequency  Note.confidence
# Duration                  -0.023755        -0.234207
# Loudness                   0.116591        -0.320799
# LogAttackTime             -0.142450        -0.225773
# Tempo                     -0.055689        -0.125349
# Tempo.confidence          -0.061536         0.280368
# TemporalCentroid           0.158615         0.018859
# SingleEvent                     NaN              NaN
# Loop                      -0.147280         0.264528
# Tonality.confidence        0.090452         0.062282
# DynamicRange              -0.004028        -0.211804
# Note.midi                  0.955458         0.177491
# Note.frequency             1.000000         0.241737
# Note.confidence            0.241737         1.000000

# %%
data['L1'] = data['Loop'].map(lambda x: 1 if x==True else 0)

# Genre y Mood deshabilitadas por ahora (ver doc)
#data['G1'] = data['Genre'].map(lambda x: 1 if x=='Genre A' else 0)
#data['M1'] = data['Mood'].map(lambda x: 1 if x=='Mood A' else 0)

# Tonality / Key
# Mapeo de las tonalidades 'en texto' a categorias numéricas
# Se necesitan k-1 variables dicotómicas, con k=len(key_to_number_list)
data['D1'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==1 else 0)
data['D2'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==2 else 0)
data['D3'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==3 else 0)
data['D4'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==4 else 0)
data['D5'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==5 else 0)
data['D6'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==6 else 0)
data['D7'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==7 else 0)
data['D8'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==8 else 0)
data['D9'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==9 else 0)
data['D10'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==10 else 0)
data['D11'] = data['Tonality'].map(lambda x: 1 if keyToNumber(x)==11 else 0)

data['T1'] = data['Tonality'].map(lambda x: 1 if x.split(' ')[1]=='major' else 0)

#data.head()

#G1 = np.asarray( data.loc[:, 'G1' ] ) # Genre
L1 = np.asarray( data.loc[:, 'L1' ] ) # Loop
#M1 = np.asarray( data.loc[:, 'M1' ] ) # Mood

D1 = np.asarray( data.loc[:, 'D1' ] )
D2 = np.asarray( data.loc[:, 'D2' ] )
D3 = np.asarray( data.loc[:, 'D3' ] )
D4 = np.asarray( data.loc[:, 'D4' ] )
D5 = np.asarray( data.loc[:, 'D5' ] )
D6 = np.asarray( data.loc[:, 'D6' ] )
D7 = np.asarray( data.loc[:, 'D7' ] )
D8 = np.asarray( data.loc[:, 'D8' ] )
D9 = np.asarray( data.loc[:, 'D9' ] )
D10 = np.asarray( data.loc[:, 'D10' ] )
D11 = np.asarray( data.loc[:, 'D11' ] )

T1 = np.asarray( data.loc[:, 'T1' ] )

# %%
Duration = np.asarray( data.loc[:, 'Duration' ] )
DynamicRange = np.asarray( data.loc[:, 'DynamicRange' ] )
LogAttackTime = np.asarray( data.loc[:, 'LogAttackTime' ] )
Loudness = np.asarray( data.loc[:, 'Loudness' ] )
Tempo = np.asarray( data.loc[:, 'Tempo' ] )
TemporalCentroid = np.asarray( data.loc[:, 'TemporalCentroid' ] )

y = LogAttackTime
#X = np.array( [Loudness, TemporalCentroid, Duration] )
# X = np.array( [DynamicRange, TemporalCentroid, Duration, G1, L1, M1, D1, D2, D3, D4, D5, D6,D7,D8,D9,D10,D11,T1])
# Según la documentación (Referencia: https://github.com/AudioCommons/ac-audio-extractor) Genre y Mood
# todavía no están correctamente implementadas, así que se descarta su valor
X = np.array( [DynamicRange, TemporalCentroid, Duration, L1, D1, D2, D3, D4, D5, D6,D7,D8,D9,D10,D11,T1])


reg_multiple(y, X).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     7.186
# Date:                Wed, 19 Dec 2018   Prob (F-statistic):           7.76e-05
# Time:                        19:26:27   Log-Likelihood:                -18.221
# No. Observations:                  32   AIC:                             58.44
# Df Residuals:                      21   BIC:                             74.57
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1131      0.206     -0.548      0.589      -0.542       0.316
# const       1.765e-14   5.43e-15      3.252      0.004    6.36e-15    2.89e-14
# x2            -0.7775      0.445     -1.746      0.095      -1.703       0.148
# x3         -6.159e-16   2.47e-16     -2.498      0.021   -1.13e-15   -1.03e-16
# x4            -1.5105      0.472     -3.203      0.004      -2.491      -0.530
# x5            -0.6144      0.441     -1.395      0.178      -1.531       0.302
# x6          3.505e-16   3.52e-16      0.996      0.331   -3.82e-16    1.08e-15
# x7            -0.9578      0.384     -2.493      0.021      -1.757      -0.159
# x8         -2.312e-15   7.98e-16     -2.897      0.009   -3.97e-15   -6.52e-16
# x9            -0.5474      0.378     -1.447      0.163      -1.334       0.240
# x10          -1.8e-15   7.04e-16     -2.557      0.018   -3.26e-15   -3.36e-16
# x11                 0          0        nan        nan           0           0
# x12            0.5264      0.349      1.510      0.146      -0.198       1.251
# x13            0.0039      0.002      2.552      0.019       0.001       0.007
# x14            5.1382      1.593      3.226      0.004       1.826       8.450
# x15            0.0658      0.028      2.359      0.028       0.008       0.124
# x16           -1.6662      0.889     -1.873      0.075      -3.516       0.184
# ==============================================================================
# Omnibus:                        5.940   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                4.285
# Skew:                          -0.793   Prob(JB):                        0.117
# Kurtosis:                       3.836   Cond. No.                     1.52e+33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.31e-61. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **Observación: Al filtrar el dataset solo utilizando las instancias que tenian los features calculados solo los features calculados con confianza alta es que se obtuvo los mejores resultados. R cuadrado (ajustado) de 0.666 y buenos valores para p.**
#
#
# ---
#
# **Siguiente:** [3 - Reducción de la dimensionalidad SVD y PCA](3%20-%20Reducción%20de%20la%20dimensionalidad%20SVD%20y%20PCA.ipynb)
